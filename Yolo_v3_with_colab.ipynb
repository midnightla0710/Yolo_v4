# %% [markdown]
# **請先點擊上方執行階段->變更執行階段，選擇GPU然後儲存**

# %% [markdown]
# **1.下載Darknet**

# %%
! git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14997, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 14997 (delta 18), reused 26 (delta 8), pack-reused 14951
# Receiving objects: 100% (14997/14997), 13.38 MiB | 23.71 MiB/s, done.
# Resolving deltas: 100% (10180/10180), done.

# %% [markdown]
# **2.查看GPU是型號與記憶體**

# %%
! nvidia-smi
# Out:
# Wed Apr 28 03:49:37 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# **3.修改Darknet內的參數**

# %%
! sed -i "s/GPU=0/GPU=1/g" /content/darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" /content/darknet/Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" /content/darknet/Makefile

# %% [markdown]
# **4.查看Darknet參數是否修改成功**

# %%
! head darknet/Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %% [markdown]
# **5.上傳train.zip**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0d828325-1e15-4f1c-b3d4-74a893340f43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0d828325-1e15-4f1c-b3d4-74a893340f43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train3.zip to train3.zip

# %% [markdown]
# **6.解壓縮train.zip並查看**

# %%
# !unzip train3.zip
# Out:
# Archive:  train3.zip
#    creating: train3/
#    creating: train3/.idea/
#   inflating: train3/.idea/.gitignore
#    creating: train3/.idea/inspectionProfiles/
#   inflating: train3/.idea/inspectionProfiles/profiles_settings.xml
#   inflating: train3/.idea/misc.xml
#   inflating: train3/.idea/modules.xml
#   inflating: train3/.idea/train2.iml
#   inflating: train3/.idea/workspace.xml
#    creating: train3/backup/
#   inflating: train3/gen_train_val.py
#   inflating: train3/obj.data
#   inflating: train3/obj.names
#   inflating: train3/predit.py
#    creating: train3/VOCdevkit/
#    creating: train3/VOCdevkit/VOC2021/
#    creating: train3/VOCdevkit/VOC2021/Annotations/
#   inflating: train3/VOCdevkit/VOC2021/Annotations/10001.xml
#   inflating: train3/VOCdevkit/VOC2021/Annotations/10002.xml
#   inflating: train3/VOCdevkit/VOC2021/Annotations/10003.xml
#   inflating: train3/VOCdevkit/VOC2021/Annotations/10004.xml
#   inflating: train3/VOCdevkit/VOC2021/Annotations/10005.xml
# ...

# %% [markdown]
# **7.編譯Darknet**

# %%
! cd darknet; make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %% [markdown]
# **8.執行voc_label.py**

# %%
# !cd train3; python voc_label.py

# %% [markdown]
# **9.開始訓練Yolo_v3模型**

# %%
# !cd train3;/content/darknet/darknet detector train /content/train3/obj.data /content/train3/yolov4-tiny-myobj.cfg /content/train3/yolov4-tiny.conv.29 -map -dont_show
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.000375, iou_loss = 0.000000, total_loss = 0.000375
#  total_bbox = 387055, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.912539), count: 4, class_loss = 0.000217, iou_loss = 0.055594, total_loss = 0.055811
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 387059, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.883328), count: 4, class_loss = 0.009360, iou_loss = 0.041278, total_loss = 0.050638
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...

# %% [markdown]
# **10.壓縮訓練完的train資料夾**

# %%
# !tar -zcf train3_finished.tar.gz train3

# %% [markdown]
# **11.查看train資料夾是否壓縮完成**

# %%
# !ls
# Out:
# darknet  sample_data  train3  train3_finished.tar.gz  train3.zip

# %% [markdown]
# **12.下載train資料夾的壓縮檔**

# %%
from google.colab import files
files.download('/content/train3_finished.tar.gz')
