# %% [markdown]
# #請先點擊上方執行階段->變更執行階段，選擇GPU然後儲存

# %% [markdown]
# #下載

# %%
! git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14730, done.
# remote: Total 14730 (delta 0), reused 0 (delta 0), pack-reused 14730
# Receiving objects: 100% (14730/14730), 13.27 MiB | 25.03 MiB/s, done.
# Resolving deltas: 100% (10020/10020), done.

# %% [markdown]
# #查看GPU是甚麼型號，有多少記憶體

# %%
! nvidia-smi
# Out:
# Sun Mar 21 00:37:13 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.56       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# #修改darknet內的參數

# %%
! sed -i "s/GPU=0/GPU=1/g" /content/darknet/Makefile
! sed -i "s/CUDNN=0/CUDNN=1/g" /content/darknet/Makefile
! sed -i "s/OPENCV=0/OPENCV=1/g" /content/darknet/Makefile

# %% [markdown]
# #查看是否修改成功

# %%
! head darknet/Makefile
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=0
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0

# %% [markdown]
# #上傳整包訓練的壓縮檔

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d5e7f6a6-a5e8-46f5-b6f9-a92095411f01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d5e7f6a6-a5e8-46f5-b6f9-a92095411f01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving yolov4-tiny-myobj.cfg to yolov4-tiny-myobj.cfg

# %% [markdown]
# #解壓縮並查看

# %%
# !tar -zxf train.tar.gz

# %%
# !cd train;ls
# Out:
# 2021_train.txt	gen_train_val.py  VOCdevkit	       yolov4-tiny-myobj.cfg
# 2021_val.txt	obj.data	  voc_label.py
# backup		obj.names	  yolov4-tiny.conv.29

# %% [markdown]
# #編譯

# %%
! cd darknet; make

# %% [markdown]
# ```
# # 此內容會顯示為程式碼
# ```
#
# #執行這個檔案

# %%
# !cd train; python voc_label.py

# %% [markdown]
# #正式開始訓練模型

# %%
# !cd train;/content/darknet/darknet detector train /content/train/obj.data /content/train/yolov4-tiny-myobj.cfg /content/train/yolov4-tiny.conv.29 -map -dont_show

# %% [markdown]
# #打包準備帶走

# %%
# !tar -zcf trained.tar.gz train

# %%
# !ls
# Out:
# darknet  sample_data  train  trained.tar.gz  train.tar.gz

# %% [markdown]
# #把剛剛打包的訓練完的壓縮檔下載下來

# %%
from google.colab import files
files.download('/content/trained.tar.gz')
